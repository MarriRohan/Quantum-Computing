# %% [markdown]
# <a href="https://colab.research.google.com/github/MarriRohan/Quantum-Computing/blob/main/Quantum_Circuit_Designer_and_Simulator%20product%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit qiskit-aer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 70.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 80.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 80.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 3.8 MB/s eta 0:00:00
# ...

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram, plot_bloch_multivector
import matplotlib.pyplot as plt

# %%
qc = QuantumCircuit(1)

qc.id(0)

print(qc)
# Out:
#    ┌───┐
# q: ┤ I ├
#    └───┘

# %%
qc = QuantumCircuit(1)

qc.x(0)

print(qc)
# Out:
#    ┌───┐
# q: ┤ X ├
#    └───┘

# %%
qc = QuantumCircuit(1)

qc.y(0)

print(qc)
# Out:
#    ┌───┐
# q: ┤ Y ├
#    └───┘

# %%
qc = QuantumCircuit(1)

qc.z(0)

print(qc)
# Out:
#    ┌───┐
# q: ┤ Z ├
#    └───┘

# %%
qc = QuantumCircuit(1)

qc.h(0)

print(qc)
# Out:
#    ┌───┐
# q: ┤ H ├
#    └───┘

# %%
state = Statevector.from_instruction(qc)

plot_bloch_multivector(state)
plt.show()

# %%
qc = QuantumCircuit(1)

qc.s(0)

print(qc)
# Out:
#    ┌───┐
# q: ┤ S ├
#    └───┘

# %%
qc = QuantumCircuit(1)

qc.t(0)

print(qc)
# Out:
#    ┌───┐
# q: ┤ T ├
#    └───┘

# %%
from numpy import pi

qc = QuantumCircuit(1)

qc.rx(pi/2, 0)
qc.ry(pi/2, 0)
qc.rz(pi/2, 0)

print(qc)
# Out:
#    ┌─────────┐┌─────────┐┌─────────┐
# q: ┤ Rx(π/2) ├┤ Ry(π/2) ├┤ Rz(π/2) ├
#    └─────────┘└─────────┘└─────────┘

# %%
qc = QuantumCircuit(1, 1)

qc.h(0)
qc.measure(0, 0)

print(qc)
# Out:
#      ┌───┐┌─┐
#   q: ┤ H ├┤M├
#      └───┘└╥┘
# c: 1/══════╩═
#            0

# %%
simulator = AerSimulator()

result = simulator.run(qc, shots=1024).result()

counts = result.get_counts()

print(counts)

plot_histogram(counts)
plt.show()
# Out:
# {'0': 533, '1': 491}

# %%
 qc = QuantumCircuit(2)

qc.x(0)
qc.cx(0, 1)

print(qc)
# Out:
#      ┌───┐
# q_0: ┤ X ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘

# %%
qc = QuantumCircuit(2)

qc.h(0)
qc.cz(0, 1)

print(qc)
# Out:
#      ┌───┐
# q_0: ┤ H ├─■─
#      └───┘ │
# q_1: ──────■─

# %%
qc = QuantumCircuit(2)

qc.x(0)
qc.swap(0, 1)

print(qc)
# Out:
#      ┌───┐
# q_0: ┤ X ├─X─
#      └───┘ │
# q_1: ──────X─

# %%
qc = QuantumCircuit(3)

qc.x(0)
qc.x(1)
qc.ccx(0, 1, 2)

print(qc)
# Out:
#      ┌───┐
# q_0: ┤ X ├──■──
#      ├───┤  │
# q_1: ┤ X ├──■──
#      └───┘┌─┴─┐
# q_2: ─────┤ X ├
#           └───┘

# %%
qc = QuantumCircuit(2)

qc.h(0)
qc.cx(0, 1)

print(qc)
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘

# %%
state = Statevector.from_instruction(qc)

print(state)
# Out:
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))

# %%
plot_bloch_multivector(state)
plt.show()

# %%
qc = QuantumCircuit(2, 2)

qc.h(0)
qc.cx(0, 1)

qc.measure([0, 1], [0, 1])

simulator = AerSimulator()

result = simulator.run(qc, shots=1024).result()

counts = result.get_counts()

print(counts)

plot_histogram(counts)
plt.show()
# Out:
# {'11': 535, '00': 489}

# %%
qc = QuantumCircuit(3)

qc.h(0)
qc.cx(0, 1)
qc.cx(1, 2)

print(qc)
# Out:
#      ┌───┐
# q_0: ┤ H ├──■───────
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├──■──
#           └───┘┌─┴─┐
# q_2: ──────────┤ X ├
#                └───┘

# %%
state = Statevector.from_instruction(qc)

print(state)
# Out:
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.        +0.j, 0.        +0.j, 0.        +0.j,
#              0.        +0.j, 0.70710678+0.j],
#             dims=(2, 2, 2))

# %%
qc = QuantumCircuit(3, 3)

qc.h(0)
qc.cx(0, 1)
qc.cx(1, 2)

qc.measure([0, 1, 2], [0, 1, 2])

simulator = AerSimulator()

result = simulator.run(qc, shots=1024).result()

counts = result.get_counts()

print(counts)

plot_histogram(counts)
plt.show()
# Out:
# {'111': 510, '000': 514}

# %%
qc = QuantumCircuit(2)

qc.x(0)
qc.swap(0, 1)

print(qc)
# Out:
#      ┌───┐
# q_0: ┤ X ├─X─
#      └───┘ │
# q_1: ──────X─

# %%
qc = QuantumCircuit(3)

qc.x(0)
qc.x(1)
qc.ccx(0, 1, 2)

print(qc)
# Out:
#      ┌───┐
# q_0: ┤ X ├──■──
#      ├───┤  │
# q_1: ┤ X ├──■──
#      └───┘┌─┴─┐
# q_2: ─────┤ X ├
#           └───┘

# %%
qc = QuantumCircuit(2)

qc.h(0)
qc.cx(0, 1)

print(qc)
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘

# %%
state = Statevector.from_instruction(qc)

print(state)
# Out:
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))

# %%
qc = QuantumCircuit(2, 2)

qc.h(0)
qc.cx(0, 1)

qc.measure([0, 1], [0, 1])

simulator = AerSimulator()
result = simulator.run(qc, shots=1024).result()

counts = result.get_counts()

print(counts)

plot_histogram(counts)
plt.show()
# Out:
# {'11': 506, '00': 518}

# %%
qc = QuantumCircuit(2)

qc.h(0)
qc.cx(0, 1)

state = Statevector.from_instruction(qc)

print(state)
# Out:
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))

# %%
plot_bloch_multivector(state)
plt.show()

# %%
qc = QuantumCircuit(3)

qc.x(0)
qc.x(1)
qc.ccx(0, 1, 2)

print(qc)
# Out:
#      ┌───┐
# q_0: ┤ X ├──■──
#      ├───┤  │
# q_1: ┤ X ├──■──
#      └───┘┌─┴─┐
# q_2: ─────┤ X ├
#           └───┘

# %%
qc = QuantumCircuit(3, 3)

qc.x(0)
qc.x(1)
qc.ccx(0, 1, 2)

qc.measure([0, 1, 2], [0, 1, 2])

simulator = AerSimulator()

result = simulator.run(qc, shots=1024).result()

counts = result.get_counts()

print(counts)

plot_histogram(counts)
plt.show()
# Out:
# {'111': 1024}

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

circuit_names = [
    "Identity (I)",
    "Pauli-X",
    "Pauli-Y",
    "Pauli-Z",
    "Hadamard (H)",
    "Phase-S",
    "Phase-T",
    "CNOT (CX)",
    "CZ",
    "SWAP",
    "Toffoli (CCX)",
    "Bell State",
    "GHZ State"
]

dropdown = widgets.Dropdown(
    options=circuit_names,
    description="Circuit:",
    style={'description_width': 'initial'}
)

button = widgets.Button(
    description="Run Circuit",
    button_style='primary'
)

output = widgets.Output()

def run_circuit(b):

    with output:
        clear_output()

        name = dropdown.value

        if name == "Identity (I)":
            qc = QuantumCircuit(1)
            qc.id(0)

        elif name == "Pauli-X":
            qc = QuantumCircuit(1)
            qc.x(0)

        elif name == "Pauli-Y":
            qc = QuantumCircuit(1)
            qc.y(0)

        elif name == "Pauli-Z":
            qc = QuantumCircuit(1)
            qc.z(0)

        elif name == "Hadamard (H)":
            qc = QuantumCircuit(1)
            qc.h(0)

        elif name == "Phase-S":
            qc = QuantumCircuit(1)
            qc.s(0)

        elif name == "Phase-T":
            qc = QuantumCircuit(1)
            qc.t(0)

        elif name == "CNOT (CX)":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.cx(0, 1)

        elif name == "CZ":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.h(1)
            qc.cz(0, 1)

        elif name == "SWAP":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.swap(0, 1)

        elif name == "Toffoli (CCX)":
            qc = QuantumCircuit(3)
            qc.x(0)
            qc.x(1)
            qc.ccx(0, 1, 2)

        elif name == "Bell State":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.cx(0, 1)

        elif name == "GHZ State":
            qc = QuantumCircuit(3)
            qc.h(0)
            qc.cx(0, 1)
            qc.cx(1, 2)

        print("Selected Circuit:")
        print(name)

        print("\nCircuit Diagram:")
        print(qc)


        state = Statevector.from_instruction(qc)

        print("\nStatevector:")
        print(state)


        print("\nState Visualization:")

        display(plot_bloch_multivector(state))


        measured_qc = qc.copy()

        measured_qc.measure_all()

        simulator = AerSimulator()

        result = simulator.run(
            measured_qc,
            shots=1024
        ).result()

        counts = result.get_counts()

        print("\nMeasurement Results:")
        print(counts)


        print("\nMeasurement Histogram:")

        plot_histogram(counts)
        plt.show()

button.on_click(run_circuit)

display(dropdown)
display(button)
display(output)
# Out:
# Dropdown(description='Circuit:', options=('Identity (I)', 'Pauli-X', 'Pauli-Y', 'Pauli-Z', 'Hadamard (H)', 'Ph…
# Button(button_style='primary', description='Run Circuit', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

circuit_names = [
    "Identity (I)",
    "Pauli-X",
    "Pauli-Y",
    "Pauli-Z",
    "Hadamard (H)",
    "Phase-S",
    "Phase-T",
    "CNOT (CX)",
    "CZ",
    "SWAP",
    "Toffoli (CCX)",
    "Bell State",
    "GHZ State"
]

dropdown = widgets.Dropdown(
    options=circuit_names,
    description="Circuit:",
    style={'description_width': 'initial'}
)

button = widgets.Button(
    description="Run Circuit",
    button_style='primary'
)

output = widgets.Output()

def run_circuit(b):

    with output:
        clear_output()

        name = dropdown.value

        if name == "Identity (I)":
            qc = QuantumCircuit(1)
            qc.id(0)

        elif name == "Pauli-X":
            qc = QuantumCircuit(1)
            qc.x(0)

        elif name == "Pauli-Y":
            qc = QuantumCircuit(1)
            qc.y(0)

        elif name == "Pauli-Z":
            qc = QuantumCircuit(1)
            qc.z(0)

        elif name == "Hadamard (H)":
            qc = QuantumCircuit(1)
            qc.h(0)

        elif name == "Phase-S":
            qc = QuantumCircuit(1)
            qc.s(0)

        elif name == "Phase-T":
            qc = QuantumCircuit(1)
            qc.t(0)

        elif name == "CNOT (CX)":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.cx(0, 1)

        elif name == "CZ":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.h(1)
            qc.cz(0, 1)

        elif name == "SWAP":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.swap(0, 1)

        elif name == "Toffoli (CCX)":
            qc = QuantumCircuit(3)
            qc.x(0)
            qc.x(1)
            qc.ccx(0, 1, 2)

        elif name == "Bell State":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.cx(0, 1)

        elif name == "GHZ State":
            qc = QuantumCircuit(3)
            qc.h(0)
            qc.cx(0, 1)
            qc.cx(1, 2)

        print("Selected Circuit:")
        print(name)

        print("\nCircuit Diagram:")
        print(qc)


        state = Statevector.from_instruction(qc)

        print("\nStatevector:")
        print(state)


        print("\nState Visualization:")

        display(plot_bloch_multivector(state))


        measured_qc = qc.copy()

        measured_qc.measure_all()

        simulator = AerSimulator()

        result = simulator.run(
            measured_qc,
            shots=1024
        ).result()

        counts = result.get_counts()

        print("\nMeasurement Results:")
        print(counts)


        print("\nMeasurement Histogram:")

        plot_histogram(counts)
        plt.show()

button.on_click(run_circuit)

display(dropdown)
display(button)
display(output)
# Out:
# Dropdown(description='Circuit:', options=('Identity (I)', 'Pauli-X', 'Pauli-Y', 'Pauli-Z', 'Hadamard (H)', 'Ph…
# Button(button_style='primary', description='Run Circuit', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

circuit_names = [
    "Identity (I)",
    "Pauli-X",
    "Pauli-Y",
    "Pauli-Z",
    "Hadamard (H)",
    "Phase-S",
    "Phase-T",
    "CNOT (CX)",
    "CZ",
    "SWAP",
    "Toffoli (CCX)",
    "Bell State",
    "GHZ State"
]

dropdown = widgets.Dropdown(
    options=circuit_names,
    description="Circuit:",
    style={'description_width': 'initial'}
)

button = widgets.Button(
    description="Run Circuit",
    button_style='primary'
)

output = widgets.Output()

def run_circuit(b):

    with output:
        clear_output()

        name = dropdown.value

        if name == "Identity (I)":
            qc = QuantumCircuit(1)
            qc.id(0)

        elif name == "Pauli-X":
            qc = QuantumCircuit(1)
            qc.x(0)

        elif name == "Pauli-Y":
            qc = QuantumCircuit(1)
            qc.y(0)

        elif name == "Pauli-Z":
            qc = QuantumCircuit(1)
            qc.z(0)

        elif name == "Hadamard (H)":
            qc = QuantumCircuit(1)
            qc.h(0)

        elif name == "Phase-S":
            qc = QuantumCircuit(1)
            qc.s(0)

        elif name == "Phase-T":
            qc = QuantumCircuit(1)
            qc.t(0)

        elif name == "CNOT (CX)":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.cx(0, 1)

        elif name == "CZ":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.h(1)
            qc.cz(0, 1)

        elif name == "SWAP":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.swap(0, 1)

        elif name == "Toffoli (CCX)":
            qc = QuantumCircuit(3)
            qc.x(0)
            qc.x(1)
            qc.ccx(0, 1, 2)

        elif name == "Bell State":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.cx(0, 1)

        elif name == "GHZ State":
            qc = QuantumCircuit(3)
            qc.h(0)
            qc.cx(0, 1)
            qc.cx(1, 2)

        print("Selected Circuit:")
        print(name)

        print("\nCircuit Diagram:")
        print(qc)


        state = Statevector.from_instruction(qc)

        print("\nStatevector:")
        print(state)


        print("\nState Visualization:")

        display(plot_bloch_multivector(state))


        measured_qc = qc.copy()

        measured_qc.measure_all()

        simulator = AerSimulator()

        result = simulator.run(
            measured_qc,
            shots=1024
        ).result()

        counts = result.get_counts()

        print("\nMeasurement Results:")
        print(counts)


        print("\nMeasurement Histogram:")

        plot_histogram(counts)
        plt.show()

button.on_click(run_circuit)

display(dropdown)
display(button)
display(output)
# Out:
# Dropdown(description='Circuit:', options=('Identity (I)', 'Pauli-X', 'Pauli-Y', 'Pauli-Z', 'Hadamard (H)', 'Ph…
# Button(button_style='primary', description='Run Circuit', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

circuit_names = [
    "Identity (I)",
    "Pauli-X",
    "Pauli-Y",
    "Pauli-Z",
    "Hadamard (H)",
    "Phase-S",
    "Phase-T",
    "CNOT (CX)",
    "CZ",
    "SWAP",
    "Toffoli (CCX)",
    "Bell State",
    "GHZ State"
]

dropdown = widgets.Dropdown(
    options=circuit_names,
    description="Circuit:",
    style={'description_width': 'initial'}
)

button = widgets.Button(
    description="Run Circuit",
    button_style='primary'
)

output = widgets.Output()

def run_circuit(b):

    with output:
        clear_output()

        name = dropdown.value

        if name == "Identity (I)":
            qc = QuantumCircuit(1)
            qc.id(0)

        elif name == "Pauli-X":
            qc = QuantumCircuit(1)
            qc.x(0)

        elif name == "Pauli-Y":
            qc = QuantumCircuit(1)
            qc.y(0)

        elif name == "Pauli-Z":
            qc = QuantumCircuit(1)
            qc.z(0)

        elif name == "Hadamard (H)":
            qc = QuantumCircuit(1)
            qc.h(0)

        elif name == "Phase-S":
            qc = QuantumCircuit(1)
            qc.s(0)

        elif name == "Phase-T":
            qc = QuantumCircuit(1)
            qc.t(0)

        elif name == "CNOT (CX)":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.cx(0, 1)

        elif name == "CZ":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.h(1)
            qc.cz(0, 1)

        elif name == "SWAP":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.swap(0, 1)

        elif name == "Toffoli (CCX)":
            qc = QuantumCircuit(3)
            qc.x(0)
            qc.x(1)
            qc.ccx(0, 1, 2)

        elif name == "Bell State":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.cx(0, 1)

        elif name == "GHZ State":
            qc = QuantumCircuit(3)
            qc.h(0)
            qc.cx(0, 1)
            qc.cx(1, 2)

        print("Selected Circuit:")
        print(name)

        print("\nCircuit Diagram:")
        print(qc)


        state = Statevector.from_instruction(qc)

        print("\nStatevector:")
        print(state)


        print("\nState Visualization:")

        display(plot_bloch_multivector(state))


        measured_qc = qc.copy()

        measured_qc.measure_all()

        simulator = AerSimulator()

        result = simulator.run(
            measured_qc,
            shots=1024
        ).result()

        counts = result.get_counts()

        print("\nMeasurement Results:")
        print(counts)


        print("\nMeasurement Histogram:")

        plot_histogram(counts)
        plt.show()

button.on_click(run_circuit)

display(dropdown)
display(button)
display(output)
# Out:
# Dropdown(description='Circuit:', options=('Identity (I)', 'Pauli-X', 'Pauli-Y', 'Pauli-Z', 'Hadamard (H)', 'Ph…
# Button(button_style='primary', description='Run Circuit', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

circuit_names = [
    "Identity (I)",
    "Pauli-X",
    "Pauli-Y",
    "Pauli-Z",
    "Hadamard (H)",
    "Phase-S",
    "Phase-T",
    "CNOT (CX)",
    "CZ",
    "SWAP",
    "Toffoli (CCX)",
    "Bell State",
    "GHZ State"
]

dropdown = widgets.Dropdown(
    options=circuit_names,
    description="Circuit:",
    style={'description_width': 'initial'}
)

button = widgets.Button(
    description="Run Circuit",
    button_style='primary'
)

output = widgets.Output()

def run_circuit(b):

    with output:
        clear_output()

        name = dropdown.value

        if name == "Identity (I)":
            qc = QuantumCircuit(1)
            qc.id(0)

        elif name == "Pauli-X":
            qc = QuantumCircuit(1)
            qc.x(0)

        elif name == "Pauli-Y":
            qc = QuantumCircuit(1)
            qc.y(0)

        elif name == "Pauli-Z":
            qc = QuantumCircuit(1)
            qc.z(0)

        elif name == "Hadamard (H)":
            qc = QuantumCircuit(1)
            qc.h(0)

        elif name == "Phase-S":
            qc = QuantumCircuit(1)
            qc.s(0)

        elif name == "Phase-T":
            qc = QuantumCircuit(1)
            qc.t(0)

        elif name == "CNOT (CX)":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.cx(0, 1)

        elif name == "CZ":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.h(1)
            qc.cz(0, 1)

        elif name == "SWAP":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.swap(0, 1)

        elif name == "Toffoli (CCX)":
            qc = QuantumCircuit(3)
            qc.x(0)
            qc.x(1)
            qc.ccx(0, 1, 2)

        elif name == "Bell State":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.cx(0, 1)

        elif name == "GHZ State":
            qc = QuantumCircuit(3)
            qc.h(0)
            qc.cx(0, 1)
            qc.cx(1, 2)

        print("Selected Circuit:")
        print(name)

        print("\nCircuit Diagram:")
        print(qc)


        state = Statevector.from_instruction(qc)

        print("\nStatevector:")
        print(state)


        print("\nState Visualization:")

        display(plot_bloch_multivector(state))


        measured_qc = qc.copy()

        measured_qc.measure_all()

        simulator = AerSimulator()

        result = simulator.run(
            measured_qc,
            shots=1024
        ).result()

        counts = result.get_counts()

        print("\nMeasurement Results:")
        print(counts)


        print("\nMeasurement Histogram:")

        plot_histogram(counts)
        plt.show()

button.on_click(run_circuit)

display(dropdown)
display(button)
display(output)
# Out:
# Dropdown(description='Circuit:', options=('Identity (I)', 'Pauli-X', 'Pauli-Y', 'Pauli-Z', 'Hadamard (H)', 'Ph…
# Button(button_style='primary', description='Run Circuit', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

circuit_names = [
    "Identity (I)",
    "Pauli-X",
    "Pauli-Y",
    "Pauli-Z",
    "Hadamard (H)",
    "Phase-S",
    "Phase-T",
    "CNOT (CX)",
    "CZ",
    "SWAP",
    "Toffoli (CCX)",
    "Bell State",
    "GHZ State"
]

dropdown = widgets.Dropdown(
    options=circuit_names,
    description="Circuit:",
    style={'description_width': 'initial'}
)

button = widgets.Button(
    description="Run Circuit",
    button_style='primary'
)

output = widgets.Output()

def run_circuit(b):

    with output:
        clear_output()

        name = dropdown.value

        if name == "Identity (I)":
            qc = QuantumCircuit(1)
            qc.id(0)

        elif name == "Pauli-X":
            qc = QuantumCircuit(1)
            qc.x(0)

        elif name == "Pauli-Y":
            qc = QuantumCircuit(1)
            qc.y(0)

        elif name == "Pauli-Z":
            qc = QuantumCircuit(1)
            qc.z(0)

        elif name == "Hadamard (H)":
            qc = QuantumCircuit(1)
            qc.h(0)

        elif name == "Phase-S":
            qc = QuantumCircuit(1)
            qc.s(0)

        elif name == "Phase-T":
            qc = QuantumCircuit(1)
            qc.t(0)

        elif name == "CNOT (CX)":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.cx(0, 1)

        elif name == "CZ":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.h(1)
            qc.cz(0, 1)

        elif name == "SWAP":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.swap(0, 1)

        elif name == "Toffoli (CCX)":
            qc = QuantumCircuit(3)
            qc.x(0)
            qc.x(1)
            qc.ccx(0, 1, 2)

        elif name == "Bell State":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.cx(0, 1)

        elif name == "GHZ State":
            qc = QuantumCircuit(3)
            qc.h(0)
            qc.cx(0, 1)
            qc.cx(1, 2)

        print("Selected Circuit:")
        print(name)

        print("\nCircuit Diagram:")
        print(qc)


        state = Statevector.from_instruction(qc)

        print("\nStatevector:")
        print(state)


        print("\nState Visualization:")

        display(plot_bloch_multivector(state))


        measured_qc = qc.copy()

        measured_qc.measure_all()

        simulator = AerSimulator()

        result = simulator.run(
            measured_qc,
            shots=1024
        ).result()

        counts = result.get_counts()

        print("\nMeasurement Results:")
        print(counts)


        print("\nMeasurement Histogram:")

        plot_histogram(counts)
        plt.show()

button.on_click(run_circuit)

display(dropdown)
display(button)
display(output)
# Out:
# Dropdown(description='Circuit:', options=('Identity (I)', 'Pauli-X', 'Pauli-Y', 'Pauli-Z', 'Hadamard (H)', 'Ph…
# Button(button_style='primary', description='Run Circuit', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

circuit_names = [
    "Identity (I)",
    "Pauli-X",
    "Pauli-Y",
    "Pauli-Z",
    "Hadamard (H)",
    "Phase-S",
    "Phase-T",
    "CNOT (CX)",
    "CZ",
    "SWAP",
    "Toffoli (CCX)",
    "Bell State",
    "GHZ State"
]

dropdown = widgets.Dropdown(
    options=circuit_names,
    description="Circuit:",
    style={'description_width': 'initial'}
)

button = widgets.Button(
    description="Run Circuit",
    button_style='primary'
)

output = widgets.Output()

def run_circuit(b):

    with output:
        clear_output()

        name = dropdown.value

        if name == "Identity (I)":
            qc = QuantumCircuit(1)
            qc.id(0)

        elif name == "Pauli-X":
            qc = QuantumCircuit(1)
            qc.x(0)

        elif name == "Pauli-Y":
            qc = QuantumCircuit(1)
            qc.y(0)

        elif name == "Pauli-Z":
            qc = QuantumCircuit(1)
            qc.z(0)

        elif name == "Hadamard (H)":
            qc = QuantumCircuit(1)
            qc.h(0)

        elif name == "Phase-S":
            qc = QuantumCircuit(1)
            qc.s(0)

        elif name == "Phase-T":
            qc = QuantumCircuit(1)
            qc.t(0)

        elif name == "CNOT (CX)":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.cx(0, 1)

        elif name == "CZ":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.h(1)
            qc.cz(0, 1)

        elif name == "SWAP":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.swap(0, 1)

        elif name == "Toffoli (CCX)":
            qc = QuantumCircuit(3)
            qc.x(0)
            qc.x(1)
            qc.ccx(0, 1, 2)

        elif name == "Bell State":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.cx(0, 1)

        elif name == "GHZ State":
            qc = QuantumCircuit(3)
            qc.h(0)
            qc.cx(0, 1)
            qc.cx(1, 2)

        print("Selected Circuit:")
        print(name)

        print("\nCircuit Diagram:")
        print(qc)


        state = Statevector.from_instruction(qc)

        print("\nStatevector:")
        print(state)


        print("\nState Visualization:")

        display(plot_bloch_multivector(state))


        measured_qc = qc.copy()

        measured_qc.measure_all()

        simulator = AerSimulator()

        result = simulator.run(
            measured_qc,
            shots=1024
        ).result()

        counts = result.get_counts()

        print("\nMeasurement Results:")
        print(counts)


        print("\nMeasurement Histogram:")

        plot_histogram(counts)
        plt.show()

button.on_click(run_circuit)

display(dropdown)
display(button)
display(output)
# Out:
# Dropdown(description='Circuit:', options=('Identity (I)', 'Pauli-X', 'Pauli-Y', 'Pauli-Z', 'Hadamard (H)', 'Ph…
# Button(button_style='primary', description='Run Circuit', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

circuit_names = [
    "Identity (I)",
    "Pauli-X",
    "Pauli-Y",
    "Pauli-Z",
    "Hadamard (H)",
    "Phase-S",
    "Phase-T",
    "CNOT (CX)",
    "CZ",
    "SWAP",
    "Toffoli (CCX)",
    "Bell State",
    "GHZ State"
]

dropdown = widgets.Dropdown(
    options=circuit_names,
    description="Circuit:",
    style={'description_width': 'initial'}
)

button = widgets.Button(
    description="Run Circuit",
    button_style='primary'
)

output = widgets.Output()

def run_circuit(b):

    with output:
        clear_output()

        name = dropdown.value

        if name == "Identity (I)":
            qc = QuantumCircuit(1)
            qc.id(0)

        elif name == "Pauli-X":
            qc = QuantumCircuit(1)
            qc.x(0)

        elif name == "Pauli-Y":
            qc = QuantumCircuit(1)
            qc.y(0)

        elif name == "Pauli-Z":
            qc = QuantumCircuit(1)
            qc.z(0)

        elif name == "Hadamard (H)":
            qc = QuantumCircuit(1)
            qc.h(0)

        elif name == "Phase-S":
            qc = QuantumCircuit(1)
            qc.s(0)

        elif name == "Phase-T":
            qc = QuantumCircuit(1)
            qc.t(0)

        elif name == "CNOT (CX)":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.cx(0, 1)

        elif name == "CZ":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.h(1)
            qc.cz(0, 1)

        elif name == "SWAP":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.swap(0, 1)

        elif name == "Toffoli (CCX)":
            qc = QuantumCircuit(3)
            qc.x(0)
            qc.x(1)
            qc.ccx(0, 1, 2)

        elif name == "Bell State":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.cx(0, 1)

        elif name == "GHZ State":
            qc = QuantumCircuit(3)
            qc.h(0)
            qc.cx(0, 1)
            qc.cx(1, 2)

        print("Selected Circuit:")
        print(name)

        print("\nCircuit Diagram:")
        print(qc)


        state = Statevector.from_instruction(qc)

        print("\nStatevector:")
        print(state)


        print("\nState Visualization:")

        display(plot_bloch_multivector(state))


        measured_qc = qc.copy()

        measured_qc.measure_all()

        simulator = AerSimulator()

        result = simulator.run(
            measured_qc,
            shots=1024
        ).result()

        counts = result.get_counts()

        print("\nMeasurement Results:")
        print(counts)


        print("\nMeasurement Histogram:")

        plot_histogram(counts)
        plt.show()

button.on_click(run_circuit)

display(dropdown)
display(button)
display(output)
# Out:
# Dropdown(description='Circuit:', options=('Identity (I)', 'Pauli-X', 'Pauli-Y', 'Pauli-Z', 'Hadamard (H)', 'Ph…
# Button(button_style='primary', description='Run Circuit', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

circuit_names = [
    "Identity (I)",
    "Pauli-X",
    "Pauli-Y",
    "Pauli-Z",
    "Hadamard (H)",
    "Phase-S",
    "Phase-T",
    "CNOT (CX)",
    "CZ",
    "SWAP",
    "Toffoli (CCX)",
    "Bell State",
    "GHZ State"
]

dropdown = widgets.Dropdown(
    options=circuit_names,
    description="Circuit:",
    style={'description_width': 'initial'}
)

button = widgets.Button(
    description="Run Circuit",
    button_style='primary'
)

output = widgets.Output()

def run_circuit(b):

    with output:
        clear_output()

        name = dropdown.value

        if name == "Identity (I)":
            qc = QuantumCircuit(1)
            qc.id(0)

        elif name == "Pauli-X":
            qc = QuantumCircuit(1)
            qc.x(0)

        elif name == "Pauli-Y":
            qc = QuantumCircuit(1)
            qc.y(0)

        elif name == "Pauli-Z":
            qc = QuantumCircuit(1)
            qc.z(0)

        elif name == "Hadamard (H)":
            qc = QuantumCircuit(1)
            qc.h(0)

        elif name == "Phase-S":
            qc = QuantumCircuit(1)
            qc.s(0)

        elif name == "Phase-T":
            qc = QuantumCircuit(1)
            qc.t(0)

        elif name == "CNOT (CX)":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.cx(0, 1)

        elif name == "CZ":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.h(1)
            qc.cz(0, 1)

        elif name == "SWAP":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.swap(0, 1)

        elif name == "Toffoli (CCX)":
            qc = QuantumCircuit(3)
            qc.x(0)
            qc.x(1)
            qc.ccx(0, 1, 2)

        elif name == "Bell State":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.cx(0, 1)

        elif name == "GHZ State":
            qc = QuantumCircuit(3)
            qc.h(0)
            qc.cx(0, 1)
            qc.cx(1, 2)

        print("Selected Circuit:")
        print(name)

        print("\nCircuit Diagram:")
        print(qc)


        state = Statevector.from_instruction(qc)

        print("\nStatevector:")
        print(state)


        print("\nState Visualization:")

        display(plot_bloch_multivector(state))


        measured_qc = qc.copy()

        measured_qc.measure_all()

        simulator = AerSimulator()

        result = simulator.run(
            measured_qc,
            shots=1024
        ).result()

        counts = result.get_counts()

        print("\nMeasurement Results:")
        print(counts)


        print("\nMeasurement Histogram:")

        plot_histogram(counts)
        plt.show()

button.on_click(run_circuit)

display(dropdown)
display(button)
display(output)
# Out:
# Dropdown(description='Circuit:', options=('Identity (I)', 'Pauli-X', 'Pauli-Y', 'Pauli-Z', 'Hadamard (H)', 'Ph…
# Button(button_style='primary', description='Run Circuit', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

circuit_names = [
    "Identity (I)",
    "Pauli-X",
    "Pauli-Y",
    "Pauli-Z",
    "Hadamard (H)",
    "Phase-S",
    "Phase-T",
    "CNOT (CX)",
    "CZ",
    "SWAP",
    "Toffoli (CCX)",
    "Bell State",
    "GHZ State"
]

dropdown = widgets.Dropdown(
    options=circuit_names,
    description="Circuit:",
    style={'description_width': 'initial'}
)

button = widgets.Button(
    description="Run Circuit",
    button_style='primary'
)

output = widgets.Output()

def run_circuit(b):

    with output:
        clear_output()

        name = dropdown.value

        if name == "Identity (I)":
            qc = QuantumCircuit(1)
            qc.id(0)

        elif name == "Pauli-X":
            qc = QuantumCircuit(1)
            qc.x(0)

        elif name == "Pauli-Y":
            qc = QuantumCircuit(1)
            qc.y(0)

        elif name == "Pauli-Z":
            qc = QuantumCircuit(1)
            qc.z(0)

        elif name == "Hadamard (H)":
            qc = QuantumCircuit(1)
            qc.h(0)

        elif name == "Phase-S":
            qc = QuantumCircuit(1)
            qc.s(0)

        elif name == "Phase-T":
            qc = QuantumCircuit(1)
            qc.t(0)

        elif name == "CNOT (CX)":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.cx(0, 1)

        elif name == "CZ":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.h(1)
            qc.cz(0, 1)

        elif name == "SWAP":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.swap(0, 1)

        elif name == "Toffoli (CCX)":
            qc = QuantumCircuit(3)
            qc.x(0)
            qc.x(1)
            qc.ccx(0, 1, 2)

        elif name == "Bell State":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.cx(0, 1)

        elif name == "GHZ State":
            qc = QuantumCircuit(3)
            qc.h(0)
            qc.cx(0, 1)
            qc.cx(1, 2)

        print("Selected Circuit:")
        print(name)

        print("\nCircuit Diagram:")
        print(qc)


        state = Statevector.from_instruction(qc)

        print("\nStatevector:")
        print(state)


        print("\nState Visualization:")

        display(plot_bloch_multivector(state))


        measured_qc = qc.copy()

        measured_qc.measure_all()

        simulator = AerSimulator()

        result = simulator.run(
            measured_qc,
            shots=1024
        ).result()

        counts = result.get_counts()

        print("\nMeasurement Results:")
        print(counts)


        print("\nMeasurement Histogram:")

        plot_histogram(counts)
        plt.show()

button.on_click(run_circuit)

display(dropdown)
display(button)
display(output)
# Out:
# Dropdown(description='Circuit:', options=('Identity (I)', 'Pauli-X', 'Pauli-Y', 'Pauli-Z', 'Hadamard (H)', 'Ph…
# Button(button_style='primary', description='Run Circuit', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

circuit_names = [
    "Identity (I)",
    "Pauli-X",
    "Pauli-Y",
    "Pauli-Z",
    "Hadamard (H)",
    "Phase-S",
    "Phase-T",
    "CNOT (CX)",
    "CZ",
    "SWAP",
    "Toffoli (CCX)",
    "Bell State",
    "GHZ State"
]

dropdown = widgets.Dropdown(
    options=circuit_names,
    description="Circuit:",
    style={'description_width': 'initial'}
)

button = widgets.Button(
    description="Run Circuit",
    button_style='primary'
)

output = widgets.Output()

def run_circuit(b):

    with output:
        clear_output()

        name = dropdown.value

        if name == "Identity (I)":
            qc = QuantumCircuit(1)
            qc.id(0)

        elif name == "Pauli-X":
            qc = QuantumCircuit(1)
            qc.x(0)

        elif name == "Pauli-Y":
            qc = QuantumCircuit(1)
            qc.y(0)

        elif name == "Pauli-Z":
            qc = QuantumCircuit(1)
            qc.z(0)

        elif name == "Hadamard (H)":
            qc = QuantumCircuit(1)
            qc.h(0)

        elif name == "Phase-S":
            qc = QuantumCircuit(1)
            qc.s(0)

        elif name == "Phase-T":
            qc = QuantumCircuit(1)
            qc.t(0)

        elif name == "CNOT (CX)":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.cx(0, 1)

        elif name == "CZ":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.h(1)
            qc.cz(0, 1)

        elif name == "SWAP":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.swap(0, 1)

        elif name == "Toffoli (CCX)":
            qc = QuantumCircuit(3)
            qc.x(0)
            qc.x(1)
            qc.ccx(0, 1, 2)

        elif name == "Bell State":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.cx(0, 1)

        elif name == "GHZ State":
            qc = QuantumCircuit(3)
            qc.h(0)
            qc.cx(0, 1)
            qc.cx(1, 2)

        print("Selected Circuit:")
        print(name)

        print("\nCircuit Diagram:")
        print(qc)


        state = Statevector.from_instruction(qc)

        print("\nStatevector:")
        print(state)


        print("\nState Visualization:")

        display(plot_bloch_multivector(state))


        measured_qc = qc.copy()

        measured_qc.measure_all()

        simulator = AerSimulator()

        result = simulator.run(
            measured_qc,
            shots=1024
        ).result()

        counts = result.get_counts()

        print("\nMeasurement Results:")
        print(counts)


        print("\nMeasurement Histogram:")

        plot_histogram(counts)
        plt.show()

button.on_click(run_circuit)

display(dropdown)
display(button)
display(output)
# Out:
# Dropdown(description='Circuit:', options=('Identity (I)', 'Pauli-X', 'Pauli-Y', 'Pauli-Z', 'Hadamard (H)', 'Ph…
# Button(button_style='primary', description='Run Circuit', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

circuit_names = [
    "Identity (I)",
    "Pauli-X",
    "Pauli-Y",
    "Pauli-Z",
    "Hadamard (H)",
    "Phase-S",
    "Phase-T",
    "CNOT (CX)",
    "CZ",
    "SWAP",
    "Toffoli (CCX)",
    "Bell State",
    "GHZ State"
]

dropdown = widgets.Dropdown(
    options=circuit_names,
    description="Circuit:",
    style={'description_width': 'initial'}
)

button = widgets.Button(
    description="Run Circuit",
    button_style='primary'
)

output = widgets.Output()

def run_circuit(b):

    with output:
        clear_output()

        name = dropdown.value

        if name == "Identity (I)":
            qc = QuantumCircuit(1)
            qc.id(0)

        elif name == "Pauli-X":
            qc = QuantumCircuit(1)
            qc.x(0)

        elif name == "Pauli-Y":
            qc = QuantumCircuit(1)
            qc.y(0)

        elif name == "Pauli-Z":
            qc = QuantumCircuit(1)
            qc.z(0)

        elif name == "Hadamard (H)":
            qc = QuantumCircuit(1)
            qc.h(0)

        elif name == "Phase-S":
            qc = QuantumCircuit(1)
            qc.s(0)

        elif name == "Phase-T":
            qc = QuantumCircuit(1)
            qc.t(0)

        elif name == "CNOT (CX)":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.cx(0, 1)

        elif name == "CZ":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.h(1)
            qc.cz(0, 1)

        elif name == "SWAP":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.swap(0, 1)

        elif name == "Toffoli (CCX)":
            qc = QuantumCircuit(3)
            qc.x(0)
            qc.x(1)
            qc.ccx(0, 1, 2)

        elif name == "Bell State":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.cx(0, 1)

        elif name == "GHZ State":
            qc = QuantumCircuit(3)
            qc.h(0)
            qc.cx(0, 1)
            qc.cx(1, 2)

        print("Selected Circuit:")
        print(name)

        print("\nCircuit Diagram:")
        print(qc)


        state = Statevector.from_instruction(qc)

        print("\nStatevector:")
        print(state)


        print("\nState Visualization:")

        display(plot_bloch_multivector(state))


        measured_qc = qc.copy()

        measured_qc.measure_all()

        simulator = AerSimulator()

        result = simulator.run(
            measured_qc,
            shots=1024
        ).result()

        counts = result.get_counts()

        print("\nMeasurement Results:")
        print(counts)


        print("\nMeasurement Histogram:")

        plot_histogram(counts)
        plt.show()

button.on_click(run_circuit)

display(dropdown)
display(button)
display(output)
# Out:
# Dropdown(description='Circuit:', options=('Identity (I)', 'Pauli-X', 'Pauli-Y', 'Pauli-Z', 'Hadamard (H)', 'Ph…
# Button(button_style='primary', description='Run Circuit', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

circuit_names = [
    "Identity (I)",
    "Pauli-X",
    "Pauli-Y",
    "Pauli-Z",
    "Hadamard (H)",
    "Phase-S",
    "Phase-T",
    "CNOT (CX)",
    "CZ",
    "SWAP",
    "Toffoli (CCX)",
    "Bell State",
    "GHZ State"
]

dropdown = widgets.Dropdown(
    options=circuit_names,
    description="Circuit:",
    style={'description_width': 'initial'}
)

button = widgets.Button(
    description="Run Circuit",
    button_style='primary'
)

output = widgets.Output()

def run_circuit(b):

    with output:
        clear_output()

        name = dropdown.value

        if name == "Identity (I)":
            qc = QuantumCircuit(1)
            qc.id(0)

        elif name == "Pauli-X":
            qc = QuantumCircuit(1)
            qc.x(0)

        elif name == "Pauli-Y":
            qc = QuantumCircuit(1)
            qc.y(0)

        elif name == "Pauli-Z":
            qc = QuantumCircuit(1)
            qc.z(0)

        elif name == "Hadamard (H)":
            qc = QuantumCircuit(1)
            qc.h(0)

        elif name == "Phase-S":
            qc = QuantumCircuit(1)
            qc.s(0)

        elif name == "Phase-T":
            qc = QuantumCircuit(1)
            qc.t(0)

        elif name == "CNOT (CX)":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.cx(0, 1)

        elif name == "CZ":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.h(1)
            qc.cz(0, 1)

        elif name == "SWAP":
            qc = QuantumCircuit(2)
            qc.x(0)
            qc.swap(0, 1)

        elif name == "Toffoli (CCX)":
            qc = QuantumCircuit(3)
            qc.x(0)
            qc.x(1)
            qc.ccx(0, 1, 2)

        elif name == "Bell State":
            qc = QuantumCircuit(2)
            qc.h(0)
            qc.cx(0, 1)

        elif name == "GHZ State":
            qc = QuantumCircuit(3)
            qc.h(0)
            qc.cx(0, 1)
            qc.cx(1, 2)

        print("Selected Circuit:")
        print(name)

        print("\nCircuit Diagram:")
        print(qc)


        state = Statevector.from_instruction(qc)

        print("\nStatevector:")
        print(state)


        print("\nState Visualization:")

        display(plot_bloch_multivector(state))


        measured_qc = qc.copy()

        measured_qc.measure_all()

        simulator = AerSimulator()

        result = simulator.run(
            measured_qc,
            shots=1024
        ).result()

        counts = result.get_counts()

        print("\nMeasurement Results:")
        print(counts)


        print("\nMeasurement Histogram:")

        plot_histogram(counts)
        plt.show()

button.on_click(run_circuit)

display(dropdown)
display(button)
display(output)
# Out:
# Dropdown(description='Circuit:', options=('Identity (I)', 'Pauli-X', 'Pauli-Y', 'Pauli-Z', 'Hadamard (H)', 'Ph…
# Button(button_style='primary', description='Run Circuit', style=ButtonStyle())
# Output()
